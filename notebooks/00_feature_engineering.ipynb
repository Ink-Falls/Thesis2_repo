# %%
import pandas as pd
import numpy as np

# %%
# Initializes the dataset
df = pd.read_csv(r"C:\Users\johnl\Downloads\Dengue-Dataset.csv")
df
# Out:
#       Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0       Male   21              14.8              48              47
# 1       Male   30              15.0              47              49
# 2       Male   51              16.3              41              48
# 3     Female   26              12.3              46              49
# 4       Male   35              16.1              45              46
# ...      ...  ...               ...             ...             ...
# 1518  Female   54              17.2              41              48
# 1519    Male   23              16.8              47              40
# 1520    Male   24              15.9              46              46
# 1521    Male   49              13.2              41              49
# 1522    Male   49              13.2              41              44
#
#       Monocytes(%)  Eosinophils(%)  RBC  HCT(%)  MCV(fl)  MCH(pg)  MCHC(g/dl)  \
# ...

# %%
# Starts the data cleaning process
df = df.drop_duplicates()
df = df.reset_index()
df
# Out:
#       index  Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0         0    Male   21              14.8              48              47
# 1         1    Male   30              15.0              47              49
# 2         2    Male   51              16.3              41              48
# 3         3  Female   26              12.3              46              49
# 4         4    Male   35              16.1              45              46
# ...     ...     ...  ...               ...             ...             ...
# 1506   1518  Female   54              17.2              41              48
# 1507   1519    Male   23              16.8              47              40
# 1508   1520    Male   24              15.9              46              46
# 1509   1521    Male   49              13.2              41              49
# 1510   1522    Male   49              13.2              41              44
#
# ...

# %%
# Counts the entries
df.describe()
# Out:
#              index          Age  Hemoglobin(g/dl)  Neutrophils(%)  \
# count  1511.000000  1511.000000       1511.000000     1511.000000
# mean    764.228326    40.380543         14.511203       44.508273
# std     439.998513    15.286972          1.629524        4.312130
# min       0.000000     5.000000         10.400000       29.000000
# 25%     385.500000    28.000000         13.200000       42.000000
# 50%     767.000000    39.000000         14.600000       45.000000
# 75%    1144.500000    53.000000         15.800000       48.000000
# max    1522.000000    78.000000         17.500000       60.000000
#
#        Lymphocytes(%)  Monocytes(%)  Eosinophils(%)          RBC       HCT(%)  \
# count     1511.000000   1511.000000     1511.000000  1511.000000  1511.000000
# mean        43.578425      3.273329        3.082065     4.761085    45.187890
# std          4.946365      1.212003        0.997289     0.721822     3.578648
# ...

# %%
# Checks for null values in the entries
df.isnull().sum()
# Out:
# index                          0
# Gender                         0
# Age                            0
# Hemoglobin(g/dl)               0
# Neutrophils(%)                 0
# Lymphocytes(%)                 0
# Monocytes(%)                   0
# Eosinophils(%)                 0
# RBC                            0
# HCT(%)                         0
# MCV(fl)                        0
# MCH(pg)                        0
# MCHC(g/dl)                     0
# RDW-CV(%)                      0
# Total Platelet Count(/cumm)    0
# MPV(fl)                        0
# PDW(%)                         0
# PCT(%)                         0
# Total WBC count(/cumm)         0
# Result                         0
# dtype: int64

# %%
# Checks the column data type
df.dtypes
# Out:
# index                            int64
# Gender                          object
# Age                              int64
# Hemoglobin(g/dl)               float64
# Neutrophils(%)                   int64
# Lymphocytes(%)                   int64
# Monocytes(%)                     int64
# Eosinophils(%)                   int64
# RBC                              int64
# HCT(%)                         float64
# MCV(fl)                        float64
# MCH(pg)                        float64
# MCHC(g/dl)                     float64
# RDW-CV(%)                      float64
# Total Platelet Count(/cumm)      int64
# MPV(fl)                        float64
# PDW(%)                         float64
# PCT(%)                         float64
# Total WBC count(/cumm)           int64
# Result                          object
# dtype: object

# %%
# Saves the cleaned dataset as df1
df1 = df
df1
# Out:
#       index  Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0         0    Male   21              14.8              48              47
# 1         1    Male   30              15.0              47              49
# 2         2    Male   51              16.3              41              48
# 3         3  Female   26              12.3              46              49
# 4         4    Male   35              16.1              45              46
# ...     ...     ...  ...               ...             ...             ...
# 1506   1518  Female   54              17.2              41              48
# 1507   1519    Male   23              16.8              47              40
# 1508   1520    Male   24              15.9              46              46
# 1509   1521    Male   49              13.2              41              49
# 1510   1522    Male   49              13.2              41              44
#
# ...

# %%
# Adds a new column that checks if the person has a low platelet count
df["Low_Platelet"] = df["Total Platelet Count(/cumm)"] < 100000
df.describe
# Out:
# <bound method NDFrame.describe of       index  Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0         0    Male   21              14.8              48              47
# 1         1    Male   30              15.0              47              49
# 2         2    Male   51              16.3              41              48
# 3         3  Female   26              12.3              46              49
# 4         4    Male   35              16.1              45              46
# ...     ...     ...  ...               ...             ...             ...
# 1506   1518  Female   54              17.2              41              48
# 1507   1519    Male   23              16.8              47              40
# 1508   1520    Male   24              15.9              46              46
# 1509   1521    Male   49              13.2              41              49
# 1510   1522    Male   49              13.2              41              44
#
# ...

# %%
# Saves the cleaned dataset with the low platelet column as df2
df2 = df
df2
# Out:
#       index  Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0         0    Male   21              14.8              48              47
# 1         1    Male   30              15.0              47              49
# 2         2    Male   51              16.3              41              48
# 3         3  Female   26              12.3              46              49
# 4         4    Male   35              16.1              45              46
# ...     ...     ...  ...               ...             ...             ...
# 1506   1518  Female   54              17.2              41              48
# 1507   1519    Male   23              16.8              47              40
# 1508   1520    Male   24              15.9              46              46
# 1509   1521    Male   49              13.2              41              49
# 1510   1522    Male   49              13.2              41              44
#
# ...

# %%
# Adds a new column that checks for a person's Neutrophil-to-Lymphocyte Ratio
df["NLR"] = df["Neutrophils(%)"] / df["Lymphocytes(%)"].replace(0, np.nan)
df.describe
# Out:
# <bound method NDFrame.describe of       index  Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0         0    Male   21              14.8              48              47
# 1         1    Male   30              15.0              47              49
# 2         2    Male   51              16.3              41              48
# 3         3  Female   26              12.3              46              49
# 4         4    Male   35              16.1              45              46
# ...     ...     ...  ...               ...             ...             ...
# 1506   1518  Female   54              17.2              41              48
# 1507   1519    Male   23              16.8              47              40
# 1508   1520    Male   24              15.9              46              46
# 1509   1521    Male   49              13.2              41              49
# 1510   1522    Male   49              13.2              41              44
#
# ...

# %%
# Adds a new column that checks for a person's Platelet-to-Lymphocyte Ratio
df["PLR"] = df["Total Platelet Count(/cumm)"] / df["Lymphocytes(%)"].replace(0, np.nan)
df.describe
# Out:
# <bound method NDFrame.describe of       index  Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0         0    Male   21              14.8              48              47
# 1         1    Male   30              15.0              47              49
# 2         2    Male   51              16.3              41              48
# 3         3  Female   26              12.3              46              49
# 4         4    Male   35              16.1              45              46
# ...     ...     ...  ...               ...             ...             ...
# 1506   1518  Female   54              17.2              41              48
# 1507   1519    Male   23              16.8              47              40
# 1508   1520    Male   24              15.9              46              46
# 1509   1521    Male   49              13.2              41              49
# 1510   1522    Male   49              13.2              41              44
#
# ...

# %%
# Saves the cleaned dataset with the NLR and PLR column as df3
df = df.drop(columns=["Low_Platelet"], errors="ignore")
df3 = df.copy()
df3
# Out:
#       index  Gender  Age  Hemoglobin(g/dl)  Neutrophils(%)  Lymphocytes(%)  \
# 0         0    Male   21              14.8              48              47
# 1         1    Male   30              15.0              47              49
# 2         2    Male   51              16.3              41              48
# 3         3  Female   26              12.3              46              49
# 4         4    Male   35              16.1              45              46
# ...     ...     ...  ...               ...             ...             ...
# 1506   1518  Female   54              17.2              41              48
# 1507   1519    Male   23              16.8              47              40
# 1508   1520    Male   24              15.9              46              46
# 1509   1521    Male   49              13.2              41              49
# 1510   1522    Male   49              13.2              41              44
#
# ...

# %%
# Build and export baseline/ratio/threshold per spec without mutating source DataFrames
import os
import pandas as pd

# Source DataFrames expected from previous cells:
# df1: baseline cleaned (no Low_Platelet, no NLR, no PLR)
# df2: has Low_Platelet flag added
# df3: has NLR and PLR added; Low_Platelet removed

# Validate presence
missing = [name for name in ("df1", "df2", "df3") if name not in globals() or not isinstance(globals()[name], pd.DataFrame)]
if missing:
    raise RuntimeError(f"Missing required DataFrames: {', '.join(missing)}. Re-run earlier cells.")

# Columns to control
ratio_cols = ["NLR", "PLR"]
low_platelet_col = "Low_Platelet"

# Construct outputs per spec
baseline_df = globals()["df1"].copy()
baseline_df = baseline_df.drop(columns=[low_platelet_col] + ratio_cols, errors="ignore")

ratio_df = globals()["df3"].copy()
ratio_df = ratio_df.drop(columns=[low_platelet_col], errors="ignore")
# Ensure NLR/PLR exist; if not, create from df
if not set(ratio_cols).issubset(ratio_df.columns):
    if "df" in globals():
        tmp = globals()["df"].copy()
        for col in ratio_cols:
            if col in tmp.columns and col not in ratio_df.columns:
                ratio_df[col] = tmp[col]

threshold_df = globals()["df2"].copy()
threshold_df = threshold_df.drop(columns=ratio_cols, errors="ignore")
# Ensure Low_Platelet exists; if missing, recompute
if low_platelet_col not in threshold_df.columns and "df" in globals():
    tmp = globals()["df"].copy()
    if low_platelet_col in tmp.columns:
        threshold_df[low_platelet_col] = tmp[low_platelet_col]

# Export paths
save_dir = r"c:\\Users\\johnl\\Downloads"
os.makedirs(save_dir, exist_ok=True)

out_files = {
    "baseline": os.path.join(save_dir, "baseline.csv"),
    "ratio": os.path.join(save_dir, "ratio.csv"),
    "threshold": os.path.join(save_dir, "threshold.csv"),
}

baseline_df.to_csv(out_files["baseline"], index=False)
ratio_df.to_csv(out_files["ratio"], index=False)
threshold_df.to_csv(out_files["threshold"], index=False)

print("Exported:")
print(f" - baseline: {out_files['baseline']} (shape={baseline_df.shape})")
print(f" - ratio: {out_files['ratio']} (shape={ratio_df.shape})")
print(f" - threshold: {out_files['threshold']} (shape={threshold_df.shape})")
# Out:
# Exported:
#  - baseline: c:\\Users\\johnl\\Downloads\baseline.csv (shape=(1511, 20))
#  - ratio: c:\\Users\\johnl\\Downloads\ratio.csv (shape=(1511, 22))
#  - threshold: c:\\Users\\johnl\\Downloads\threshold.csv (shape=(1511, 21))
